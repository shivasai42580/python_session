# %% [markdown]
# # Variables:

# %%
number=100
number
# Out:
# 100

# %%
number=200
number
# Out:
# 200

# %% [markdown]
# # Rules to define variables

# %%
#uppercase
NUMBER=300
NUMBER
# Out:
# 300

# %%
#lowercase
number=400
number
# Out:
# 400

# %%
#combination of LC and UC
number=500
number
# Out:
# 500

# %%
#combination of letters and numbers,numbers as suffix
number123=600
number123
# Out:
# 600

# %%
#combination of letters and numbers,numbers as preffix
123number=700
123number
# Out:
#   Cell In[8], line 2
#     123number=700
#       ^
# SyntaxError: invalid decimal literal

# %%
#specialcharacters
number%=800
number%
# Out:
#   Cell In[9], line 3
#     number%
#            ^
# SyntaxError: invalid syntax

# %%
#underscore
number_=1000
number_
# Out:
# 1000

# %%
#keywords
if=1100
if
# Out:
#   Cell In[12], line 2
#     if=1100
#       ^
# SyntaxError: invalid syntax

# %%
sum=700 #it is a math operation it wll works but don't use as variable
sum
# Out:
# 700

# %%
#spaces not allowed
number one=1200
number one
# Out:
#   Cell In[16], line 2
#     number one=1200
#            ^
# SyntaxError: invalid syntax

# %%
number_one=1300
number_one
# Out:
# 1300

# %%
_number=1400
_number
# Out:
# 1400

# %% [markdown]
# #data type:
#  - integer -- int
#  - float ---- float
#  - string ---- str
#  - boolean --- bool
#  - complex conjuagte -- complex

# %% [markdown]
# # integer

# %%
num = 100
num
# Out:
# 100

# %%
type(num) #type of the variable
# Out:
# int

# %% [markdown]
# # complex

# %%
num=3+5j
num
# Out:
# (3+5j)

# %%
type(num)
# Out:
# complex

# %%
a=10+6j
a
# Out:
# (10+6j)

# %%
dir(a)
# Out:
# ['__abs__',
#  '__add__',
#  '__bool__',
#  '__class__',
#  '__complex__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  'conjugate',
#  'imag',
#  'real']

# %%
a.real
# Out:
# 10.0

# %%
a.imag
# Out:
# 6.0

# %%
b=a.conjugate()
b
# Out:
# (10-6j)

# %%
b.imag
# Out:
# -6.0

# %%
complex()
# Out:
# 0j

# %%
complex(4,10)
# Out:
# (4+10j)

# %% [markdown]
# #string
