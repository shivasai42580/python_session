# %%
str1='hello'
count=0
for i in str1:
    if i=='l':
        count=count+1
print(count)
# Out:
# 2

# %%
str2='hi how are you'
count=0
for i in str2:
    if i in 'aeiou':
        count+=1
print(count)
# Out:
# 6

# %%
str2='hi how are you'
count=0
vowels=''
for i in str2:
    if i in 'aeiou' and i not in vowels:
        vowels=vowels+i
print(len(vowels))
# Out:
# 5

# %%
import string
alpha=string.ascii_uppercase
for i in alpha:
    print(i,end=',')
    if(i=='K'):
        break
# Out:
# A,B,C,D,E,F,G,H,I,J,K,

# %%
for i in range(ord('Z'),ord('A')-1,-1):
    print(chr(i),end=',')
# Out:
# Z,Y,X,W,V,U,T,S,R,Q,P,O,N,M,L,K,J,I,H,G,F,E,D,C,B,A,

# %%
num=1
for i in range(ord('Z'),ord('A')-1,-1):
    print(chr(i)+str(num),end=';')
    num+=1
# Out:
# Z1;Y2;X3;W4;V5;U6;T7;S8;R9;Q10;P11;O12;N13;M14;L15;K16;J17;I18;H19;G20;F21;E22;D23;C24;B25;A26;

# %%
upper = ord('Z')  
lower = ord('a') 

for i in range(1, 27):
    print(chr(upper) + str(i) + chr(lower), end=', ')
    upper -= 1
    lower += 1
# Out:
# Z1a, Y2b, X3c, W4d, V5e, U6f, T7g, S8h, R9i, Q10j, P11k, O12l, N13m, M14n, L15o, K16p, J17q, I18r, H19s, G20t, F21u, E22v, D23w, C24x, B25y, A26z,

# %%
n=3
str1=' '
for i in range(1,n+1):
    str1=str1+str(i)
print(str1)
# Out:
#  123

# %%
def print_full_name(first, last):
    # Write your code here
    print("Hello {} {}!You just delved into python".format(first,last))
print_full_name("Ross","Taylor")
# Out:
# Hello Ross Taylor!You just delved into python

# %%
a=input()
b=input()
try:
    print(int(a)//int(b))
except Exception as e:
    print("Error Code:",e)
# Out:
#  3
# Error Code: invalid literal for int() with base 10: ' '

# %%
x,k=input().split( )
P=int(x**3)+int(x**2)+int(x)+1
if (P==int(k)):
    print(True)
else:
    print(False)
# Out:
#  1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 x,k=input().split( )
#       2 P=int(x**3)+int(x**2)+int(x)+1
#       3 if (P==int(k)):
#
# ValueError: not enough values to unpack (expected 2, got 1)
