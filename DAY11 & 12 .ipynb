# %%
print("conversation of Son and Father")
father=input("father:")
son=input("son:")
father=input("father:")
son=eval(input("son:"))
Rank=son
father=input("father:")
son=input("son:")
father=input("father:")
son=input("son:")
father=input("father:")
son=eval(input("son:"))
fee=son
father=input("father:")
son=eval(input("son:"))
sem=son
father=input("father:")
total_amount=sem*fee
print("Dad the Total amount is {} * {} i.e.{}".format(sem,fee,total_amount))
# Out:
# conversation of Son and Father
# father: Which course do you want to do?
# son: I want to pursue data science.
# father: Oh that is very nice. What is your JEE rank?
# son: 20,000
# father: And how you pursue.
# son: Payment seat.
# father: Which college will offer this?
# son: Naresh IT
# father: How much is the fee?
# son: 27000
# father: How many sems?
# son: 4
# father: How much is the total amount?
# Dad the Total amount is 4 * 27000 i.e.108000

# %%
#Write a program to repeat the string ‘‘GOOD MORNING” n times. Here ‘n’ is an integer entered by the user.
string='Good Morining'
num=eval(input("Enter a number:"))
print(" {} \n".format(string)*num)
# Out:
# Enter a number: 5
#  Good Morining
#  Good Morining
#  Good Morining
#  Good Morining
#  Good Morining

# %%
#Write a program to find average of three numbers.
num1=eval(input("Enter number1:"))
num2=eval(input("Enter number2:"))
num3=eval(input("Enter number3:"))
avg=(num1*num2*num3)/3
print("The average of {},{} and {} is {}".format(num1,num2,num3,avg))
# Out:
# Enter number1: 1
# Enter number2: 2
# Enter number3: 3
# The average of 1,2 and 3 is 2.0

# %%
# Ask for user's name and age
name = input("Enter your name: ")
age = int(input("Enter your age: "))

# Calculate the year they'll turn 100
current_year = 2025
year_turn_100 = current_year + (100 - age)

# Print the personalized message
print("Hello {}, you will turn 100 years old in the year {}.".format(name, year_turn_100))
# Out:
# Enter your name:  Shiva Sai
# Enter your age:  24
# Hello Shiva Sai, you will turn 100 years old in the year 2101.

# %%
 #Presume that a ladder is put upright against a wall. Let variables length and angle store the length of the ladder and the angle that 
 #it forms with the ground as it leans against the wall. 
 #Write a Python program to compute the height reached by the ladder on the wall for the following values of length and angle:
 #a) 16 feet and 75 degrees 
 #b) 20 feet and 0 degrees 
 #c) 24 feet and 45 degrees
 #d) 24 feet and 80 degrees
import math
length=eval(input("Enter length of the ladder in feet:"))
angle=eval(input("Enter angle it forms with the ground as it leans against the wall:"))
rad=math.radians(angle)
height=length*(math.sin(rad))
print("the height reached by the ladder on the wall is {}feet".format(int(height)))
# Out:
# Enter length of the ladder in feet: 16
# Enter angle it forms with the ground as it leans against the wall: 75
# the height reached by the ladder on the wall is 15feet

# %%
 #Write a program to calculate in how many days a work will be completed by three persons A, B and C together. A, B, C take x days, y days and z days 
 #respectively to do the job alone. The formula to calculate the number of days if they work together is xyz/(xy + yz + xz) days where x, y, and z 
 #are given as input to the program.

X=eval(input("A Enter how many days you take to complete work:"))
Y=eval(input("B Enter how many days you take to complete work:"))
Z=eval(input("C Enter how many days you take to complete work:"))
NO_OF_DAYS=X*Y*Z/(X*Y+Y*Z+X*Z)
print("The No.of Days taken by A,B and C to complete work is {}".format(int(NO_OF_DAYS)))
# Out:
# A Enter how many days you take to complete work: 10
# B Enter how many days you take to complete work: 15
# C Enter how many days you take to complete work: 20
# The No.of Days taken by A,B and C to complete work is 4

# %% [markdown]
# # Exception Handling

# %%
try:
    num1=100
    num2=200
    num3=num1+num2
    print(num3)
except:
    print("there is error")
# Out:
# 300

# %%
try:
    num1=100
    num2=0
    num3=num1/num2
    print(num3)
except:
    print("there is error")
# Out:
# there is error

# %%
try:
    num1=100
    num2=200
    num4=num1+num2
    print(num)
except:
    print("there is error")
# Out:
# there is error

# %%
try:
    num1=eval(input("enter num1:"))
    num2=eval(input("enter num2:"))
    num3=eval(input("enter num3:"))
    avg=(num1+num2+num3)/0
    print("the avg of {},{} and {} is {}".format(num1,num2,num3,avg))
except Exception as e:
    print(e)
# Out:
# enter num1: 20
# enter num2: 30
# enter num3: 40
# division by zero

# %%
try:
    num=eval(input("enter a number:"))
    square=num*num
    print("The Sqaure of {} is {}".format(num,suare))
except Exception as e:
    print(e)
# Out:
# enter a number: 10
# name 'suare' is not defined
