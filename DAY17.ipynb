# %% [markdown]
#  XYZ store plans to give festival discount to its
# customers. The store management has decided to
# give discount on the following criteria:
#  Shopping Amount   Discount Offered
#  >=500 and <1000    5%
#  >=1000 and <2000   8%
#  >=2000              10%
#  An additional discount of 5% is given to customers
# who are the members of the store. Create a program
# using user defined function that accepts the shopping
# amount as a parameter and calculates discount and net
# amount payable on the basis of the following conditions:
#  Net Payable Amount = Total Shopping Amount –
# Discount.

# %%
def XYZ_store_plans(shopping_amount):
    if(shopping_amount>=500 and shopping_amount<1000):
        discount=5*shopping_amount/100
        print("Net payable amount is {}".format(shopping_amount-discount))
    elif(shopping_amount>=1000 and shopping_amount<2000):
        discount=8*shopping_amount/100
        print("Net payable amount is {}".format(shopping_amount-discount))
    elif(shopping_amount>=2000):
        discount=10*shopping_amount/100
        print("Net payable amount is {}".format(shopping_amount-discount))
XYZ_store_plans(eval(input("Enter Total Shopping Amount:")))
# Out:
# Enter Total Shopping Amount: 1000
# Net payable amount is 920.0

# %% [markdown]
# 2)Write a program that uses a user defined function
# that accepts name and gender (as M for Male,
# F for Female) and prefixes Mr/Ms on the basis of
# the gender.

# %%
def prefixes(name,gender):
    if(gender=='M' or gender=='m'):
        print("Hello! Mr {}".format(name))
    elif(gender=='F' or gender=='f'):
        print("Hello! Mrs {}".format(name))
prefixes(input("enter your name"),input("enter your gender:M for Male/F for Female"))
# Out:
# enter your name Shiva Sai
# enter your gender:M for Male/F for Female m
# Hello! Mr Shiva Sai

# %% [markdown]
# 3)Write a program that has a user defined function
# to accept the coefficients of a quadratic equation
# in variables and calculates its determinant. For
# example : if the coefficients are stored in the
# variables a,b,c then calculate determinant as
# b2-4ac. Write the appropriate condition to check
# determinants on positive, zero and negative and
# output appropriate result.

# %%
def q_e(a,b,c):
    det=b*b-4*a*c
    if(det>0):
        print("Roots are real and different")
    elif(det==0):
        print("Roots are real and equal(same)")
    elif(det<0):
        print("Roots are imaginary(complex)")
a=eval(input("Enter X^2 co-efficent"))
b=eval(input("Enter X co-efficent"))
c=eval(input("Enter last co-efficent"))
q_e(a,b,c)
# Out:
# Enter X^2 co-efficent 1
# Enter X co-efficent 5
# Enter last co-efficent 6
# Roots are real and different

# %% [markdown]
# 4. ABC School has allotted unique token IDs from (1 to 600) to all the parents for facilitating a lucky draw
# on the day of their Annual day function. The winner
# would receive a special prize. Write a program using
# Python that helps to automate the task.(Hint: use
# random module)

# %%
import random
winning_token_id=random.randint(1,600)
#print(winning_token_id)
def lucky_draw(UID):
    if(UID==winning_token_id):
        print("Congrats!winner you would receive a special prize")
    else:
        print("Better Luck Next time")
lucky_draw(eval(input("Enter your unquie token id")))
# Out:
# Enter your unquie token id 321
# Better Luck Next time

# %% [markdown]
#  5. Write a program that implements a user defined
# function that accepts Principal Amount, Rate,
# Time
# to calculate and displays compound interest.
# (Hint: CI=P*(1+r/n)nt)

# %%
def compound_interest(Principal_Amount,Rate,Time):
    Simple_interest=Principal_Amount*Rate/100
    Total_amount=Simple_interest+Principal_Amount
    compound_interest=Rate*Total_amount/100
    Total_amount1=compound_interest+Total_amount
    print("The Total amount you have pay after {} years with compound interest is {}".format(Time,Total_amount1))
compound_interest(1000,10,2)
# Out:
# The Total amount you have pay after 2 years with compound interest is 1210.0

# %%
def add(a,b):
    print(a+b)
def sub(a,b):
    if(a>b):
        print(a-b)
    else:
        print(b-a)
def mul(a,b):
    print(a*b)
def div(a,b):
    if(a>b):
        print(a/b)
    else:
        print(b/a)
def main(a,b):
    opr=eval(input("Enter operation code ==> 1 for Addition , 2 for Subraction , 3 for Multipliaction , 4 for Division ==>"))
    if(opr==1):
        add(a,b)
    elif(opr==2):
        sub(a,b)
    elif(opr==3):
        mul(a,b)
    elif(opr==4):
        div(a,b)
    else:
        print("You entered Wrong Operation Code")
a=eval(input("Enter number1"))
b=eval(input("Enter number2"))
main(a,b)
# Out:
# Enter number1 30
# Enter number2 40
# Enter operation code ==> 1 for Addition , 2 for Subraction , 3 for Multipliaction , 4 for Division ==> 5
# You entered Wrong Operation Code
